# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
data = pd.read_csv('Obama.csv', parse_dates = ['year_month'])
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
plt.plot(data.year_month, data.approve_percent, 'o',markersize = 2, alpha = 0.3)
plt.show()

# %%
# groupby fuc
grouped = data[['year_month', 'approve_percent']].groupby('year_month').mean().reset_index()

sns.lineplot(x = "year_month", y = "approve_percent", data = data)

plt.show()

# %%
data_mean = data.groupby('year_month').mean()
data_median = data.groupby('year_month').median()


plt.plot(data_mean.index, data_mean.approve_percent, 'red')
plt.plot(data_median.index, data_median.approve_percent, 'green')
plt.plot(data.year_month, data.approve_percent, 'o',markersize = 2, alpha = 0.3)
plt.show()

# %%
data_25 = data.groupby('year_month').quantile(0.25)
data_75 = data.groupby('year_month').quantile(0.75)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-dbac677c649e> in <module>
# ----> 1 data_25 = data.groupby('year_month').quantile(0.25)
#       2 data_75 = data.groupby('year_month').quantile(0.75)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in quantile(self, q, interpolation)
#    1912                 post_processing=post_processor,
#    1913                 q=q,
# -> 1914                 interpolation=interpolation,
#    1915             )
#    1916         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_cythonized_result(self, how, grouper, aggregate, cython_dtype, needs_values, needs_mask, needs_ngroups, result_is_index, pre_processing, post_processing, **kwargs)
#    2280                 vals = obj.values
#    2281                 if pre_processing:
# -> 2282                     vals, inferences = pre_processing(vals)
#    2283                 func = partial(func, vals)
#    2284
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in pre_processor(vals)
#    1878             if is_object_dtype(vals):
#    1879                 raise TypeError(
# -> 1880                     "'quantile' cannot be performed against " "'object' dtypes!"
#    1881                 )
#    1882
#
# TypeError: 'quantile' cannot be performed against 'object' dtypes!
